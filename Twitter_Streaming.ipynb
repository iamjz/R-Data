# %%
library(rtweet)
library(tidyverse)

# %%
st <- stream_tweets(q = "", timeout = 5)
head(st)
# Out:
# Streaming tweets for 5 seconds...
# Downloading: 210 kB
# Finished streaming tweets!
# opening file input connection.
#  Imported 138 records. Simplifying...
# closing file input connection.
#   status_id          created_at          user_id            screen_name
# 1 962804274169249802 2018-02-11 21:43:21 2657631888         JBocis
# 2 962804274207084544 2018-02-11 21:43:21 592773542          _timmmmy
# 3 962804274186129409 2018-02-11 21:43:21 894459025739440129 kbeezy29
# 4 962804274186113024 2018-02-11 21:43:21 798531960662609920 ivoferreira927
# 5 962804274173501442 2018-02-11 21:43:21 848258027618799616 MariaClara8330
# 6 962804274202906624 2018-02-11 21:43:21 833333061777555457 Rafeef312
#   text
# 1 @IvanOGodfroid Existait il de son temps ?
# 2 RT @vinny2NlCE: Looks like Isaiah Thomas was holding the Cavs back...theyre looking better already
# 3 RT @BigPooh_91: GOD IS GOOD<U+203C><U+FE0F>
# ...

# %%
st <- stream_tweets(q = "boston,philadelphia", timeout = 5)
head(st)
# Out:
# Streaming tweets for 5 seconds...
# Downloading: 35 kB
# Finished streaming tweets!
# opening file input connection.
#  Imported 22 records. Simplifying...
# closing file input connection.
#   status_id          created_at          user_id            screen_name
# 1 962804326845566977 2018-02-11 21:43:34 761979183878647808 nentokesore
# 2 962804328275873792 2018-02-11 21:43:34 248162657          YianniKalouriii
# 3 962804330964365313 2018-02-11 21:43:35 3134392444         vtwill04
# 4 962804331316695041 2018-02-11 21:43:35 398094432          FUCKB0ITIM
# 5 962804331971010560 2018-02-11 21:43:35 2960463318         TheRealTjayy
# 6 962804332512137216 2018-02-11 21:43:35 2962692233         adrimasteryt
#   text
# 1 RT @feryooit: TREY SONGZ ALICIA KEYS RDBMS FOR 4TH OF SOMMELIER BREAKING BAD HAWK, SWITZERLAND. DIARRHEA FART GEEK DECORATING EMINEM FISHES
# 2 RT @BleacherReport: Cavs new weapons doing work in Boston \n\nThey lead the Celtics, 64-52 at the half. https://t.co/8dA4NiDuwC
# ...

# %%
## lookup coords (the API can be a bit picky; you may need to run the first call for COMO twice to see get the values)
lookup_coords("Columbia, MO")
# Out:
# $place
# [1] "Columbia, MO"
#
# $box
#    sw.lng    sw.lat    ne.lng    ne.lat
# -92.43348  38.86355 -92.22819  39.02944
#
# $point
#       lat       lng
#  38.95171 -92.33407
#
# attr(,"class")
# [1] "coords" "list"

# %%
st <- stream_tweets(q = lookup_coords("Austin, TX"), timeout = 5)
head(st)
# Out:
# Streaming tweets for 5 seconds...
# Downloading: 2.6 kB
# Finished streaming tweets!
# opening file input connection.
#  Imported 2 records. Simplifying...
# closing file input connection.
#   status_id          created_at          user_id            screen_name
# 1 962804428498702339 2018-02-11 21:43:58 41212709           AnewMoo
# 2 962804431204093953 2018-02-11 21:43:59 824791899118694401 Joriley_turner
#   text
# 1 @Je_suis_elite @ApophisQ86 @johncusack Haaaah..
# 2 @caseyy_leee and I are to anxious for muddy gras<f0><U+009F><U+0098><U+00A9>
#   source             reply_to_status_id reply_to_user_id   reply_to_screen_name
# 1 Twitter for iPhone 962802874643353600 810869686355316736 Je_suis_elite
# 2 Twitter for iPhone NA                 287980808          caseyy_leee
#   is_quote ... retweet_text
# 1 FALSE    ... NA
# 2 FALSE    ... NA
#   place_url                                                place_name
# 1 https://api.twitter.com/1.1/geo/id/e0060cda70f5f341.json Texas
# ...

# %%
st <- stream_tweets(q = "realDonaldTrump,HillaryClinton", timeout = 5)
head(st)
# Out:
# Streaming tweets for 5 seconds...
# Downloading: 120 kB
# Finished streaming tweets!
# opening file input connection.
#  Imported 66 records. Simplifying...
# closing file input connection.
#   status_id          created_at          user_id    screen_name
# 1 962804495167250433 2018-02-11 21:44:14 837857630  PJNoon
# 2 962804496459059203 2018-02-11 21:44:14 246371061  KelCampy
# 3 962804496391864321 2018-02-11 21:44:14 15961286   dutch163
# 4 962804496496807936 2018-02-11 21:44:14 398228119  skooniebird
# 5 962804496568016897 2018-02-11 21:44:14 1259393028 fawn_mac
# 6 962804496966578177 2018-02-11 21:44:14 727097960  LaurieWorby
#   text
# 1 @realDonaldTrump The Liberal Media's silence on the Russia Gate/Foundation Gate issues is deafening. Wake up America.
# 2 RT @LeesaEGrant: #CentralPark5.. ... Due process??? https://t.co/XzDSHsr3CF
# 3 @jcreechy @williamlegate @zainar12345 @biggeststarhere @FoxNews @SenGillibrand @realDonaldTrump https://t.co/oWwI8AYMKD
# ...
