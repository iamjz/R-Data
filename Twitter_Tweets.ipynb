# %%
library(rtweet)
# Out:
# Warning message:
# "package 'rtweet' was built under R version 3.4.3"

# %%
## search tweets (q = search query; n = desired number of tweets to return)
rt <- search_tweets(q = "rstats", n = 200, verbose = FALSE)

# %%
## search for any mention of a list of words
rt <- search_tweets("statistics OR statistical OR quantitative")
# Out:
# Searching for tweets...
# Finished collecting tweets!

# %%
## search for tweets in english that are not retweets
rt <- search_tweets("statistics OR statistical OR quantitative", lang = "en", include_rts = FALSE)
# Out:
# Searching for tweets...
# Finished collecting tweets!

# %%
cnn <- get_timeline("cnn", n = 3200)

head(cnn)
# Out:
#   status_id          created_at          user_id screen_name
# 1 959916961789603845 2018-02-03 22:30:12 759251  CNN
# 2 959913177214414848 2018-02-03 22:15:10 759251  CNN
# 3 959909441884839936 2018-02-03 22:00:19 759251  CNN
# 4 959905619691130884 2018-02-03 21:45:08 759251  CNN
# 5 959901844557500417 2018-02-03 21:30:08 759251  CNN
# 6 959898061379162116 2018-02-03 21:15:06 759251  CNN
#   text
# 1 France jails Islamic scholar on rape charge, judicial source says https://t.co/nqI0fWVgsq https://t.co/zqpgoIo3Z9
# 2 Turkish border guards are shooting at Syrian refugees, rights group says https://t.co/XlPlLUOibi https://t.co/d3wnWetWlZ
# 3 Here's a weekly roundup of the news, notes and chatter about the prospects for the next Democratic presidential race https://t.co/kdCe4eVbdf https://t.co/MHwVgAcSR7
# 4 Security faces "herculean" challenges at Super Bowl https://t.co/GNHVl3BKZm https://t.co/3wZSPNAmqI
# 5 Remembering Dr. Mathilde Krim, who broke the silence about the AIDS crisis more than three decades ago https://t.co/h1YLEIxlQ7 (via @CNNOpinion) https://t.co/szS2R3z6tp
# 6 The real shock of the Nunes memo https://t.co/GsuitVCZ6E (via @CNNOpinion) https://t.co/lGz0zyWwxy
#   source     reply_to_status_id reply_to_user_id reply_to_screen_name is_quote
# 1 SocialFlow NA                 NA               NA                   FALSE
# 2 SocialFlow NA                 NA               NA                   FALSE
# 3 SocialFlow NA                 NA               NA                   FALSE
# 4 SocialFlow NA                 NA               NA                   FALSE
# 5 SocialFlow NA                 NA               NA                   FALSE
# 6 SocialFlow NA                 NA               NA                   FALSE
#   ... retweet_text place_url place_name place_full_name place_type country
# 1 ... NA           NA        NA         NA              NA         NA
# 2 ... NA           NA        NA         NA              NA         NA
# 3 ... NA           NA        NA         NA              NA         NA
# 4 ... NA           NA        NA         NA              NA         NA
# 5 ... NA           NA        NA         NA              NA         NA
# 6 ... NA           NA        NA         NA              NA         NA
#   country_code geo_coords coords_coords bbox_coords
# 1 NA           NA, NA     NA, NA        NA, NA, NA, NA, NA, NA, NA, NA
# 2 NA           NA, NA     NA, NA        NA, NA, NA, NA, NA, NA, NA, NA
# 3 NA           NA, NA     NA, NA        NA, NA, NA, NA, NA, NA, NA, NA
# 4 NA           NA, NA     NA, NA        NA, NA, NA, NA, NA, NA, NA, NA
# 5 NA           NA, NA     NA, NA        NA, NA, NA, NA, NA, NA, NA, NA
# 6 NA           NA, NA     NA, NA        NA, NA, NA, NA, NA, NA, NA, NA

# %%
jack_favs <- get_favorites("jack", n = 3000)
# Out:
# Error in (function (user, n = 200, since_id = NULL, max_id = NULL, parse = TRUE, : object 'count' not found
# Traceback:
#
# 1. get_favorites("jack", n = 3000)
# 2. do.call("get_favorites_call", args)
# 3. get_favorites_call(user = "jack", n = 3000, since_id = NULL,
#  .     max_id = NULL, parse = TRUE, token = NULL)
# 4. Map(get_favorites_, user = user, n = n, parse = parse, token = list(token))
# 5. mapply(FUN = f, ..., SIMPLIFY = FALSE)
# 6. (function (user, n = 200, since_id = NULL, max_id = NULL, parse = TRUE,
#  .     token = NULL)
#  . {
#  .     query <- "favorites/list"
#  .     if (n > 3000) {
#  .         warning(paste0("n exceeds max favs returned per ", "token. Setting n to 3000..."),
#  .             call. = FALSE)
#  .         n <- 3000
#  .         count <- 200
#  .     }
#  .     else if (n < 200) {
#  .         count <- n
#  .     }
#  .     n.times <- rate_limit(token, query)[["remaining"]]
#  .     if (n.times == 0L)
#  .         stop("rate limit exceeded", call. = FALSE)
#  .     params <- list(user_type = user, count = count, tweet_mode = "extended")
#  .     names(params)[1] <- .id_type(user)
#  .     url <- make_url(query = query, param = params)
#  .     fav <- scroller(url, n, n.times, type = "timeline", token)
#  .     if (parse) {
#  .         fav <- tweets_with_users(fav)
#  .         usr <- users_data(fav)
#  .         if (nrow(usr) > 0L) {
#  .             uq <- !duplicated(usr$user_id)
#  .             attr(fav, "users") <- usr[uq, ]
#  .         }
#  .     }
#  .     fav
#  . })(user = dots[[1L]][[1L]], n = dots[[2L]][[1L]], parse = dots[[3L]][[1L]],
#  .     token = dots[[4L]][[1L]])

# %%
## lookup tweets using status IDs
status_ids <- c("947235015343202304", "947592785519173637", "948359545767841792", "832945737625387008")
twt <- lookup_tweets(status_ids)
twt
