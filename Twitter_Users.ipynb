# %%
library(rtweet)

# %%
## search for 1000 users using keywords bitcoin or cryptocurrency
cc <- search_users(q = "bitcoin OR cryptocurrency", n = 1000, verbose = FALSE)

## a tibble (data frame) where each observation (row) is a different user
head(cc)
# Out:
#   user_id            name
# 1 901501366664912896 Delta - Bitcoin, ICO & Cryptocurrency Portfolio
# 2 721699235033432064 Genesis Mining Promo Code - ukYlRS
# 3 3420558951         Mario
# 4 757295244635439104 Boost
# 5 700262726250049536 Cancerbola
# 6 881561327575191552 CryptoMite
#   screen_name     location
# 1 get_delta       Get the app via
# 2 GenesisPromoCde United States
# 3 OrBitcoinLove   1 first 30 coins in the #world
# 4 BoostTM
# 5 bitcoin_dude    California, USA
# 6 CryptoM173
#   description
# 1 Delta is a mobile cryptocurrency portfolio management app. Get in touch via https://t.co/9TB9Yx645M, https://t.co/LrXiSjXXIi or https://t.co/JV9Q9Y8Lnc <f0><U+009F><U+0092><U+0099>
# 2 The official Genesis Mining Promo Code that can be used to give you a 3% discount on your Bitcoin or other Cryptocurrency purchase - ukYlRS. *Affiliate Account*
# ...

# %%
## a tibble (data frame) where each observation (row) is a tweet
cc %>%
    tweets_data() %>%
    head()
# Out:
#   status_id          created_at          user_id            screen_name
# 1 959775713980231687 2018-02-03 13:08:56 901501366664912896 get_delta
# 2 959914802704539654 2018-02-03 22:21:37 721699235033432064 GenesisPromoCde
# 3 953027147073032192 2018-01-15 22:12:32 3420558951         OrBitcoinLove
# 4 959860192887410690 2018-02-03 18:44:37 757295244635439104 BoostTM
# 5 959798653371277313 2018-02-03 14:40:05 700262726250049536 bitcoin_dude
# 6 959903089795805185 2018-02-03 21:35:05 881561327575191552 CryptoM173
#   text
# 1 @Tibo_03 We need to add BitFlip to be able to add it, show your support on it here : https://t.co/Ne2NTrevJs
# 2 If you want to make transaction, you simply broadcast to the cryptocurrencys network that youre transferring ownership of some cryptocurrency of yours to someon Genesis Mining packages are available again!! Copy and paste the promo code ukYlRS to save 3% https://t.co/Aty7VuYedO
# ...

# %%
## use user_id or screen_name vector to lookup users data
users <- c("latimes", "cnn", "nytimes", "foxnews")
usrs <- lookup_users(users)

# %%
usrs
# Out:
#   user_id  name               screen_name location
# 1 16664681 Los Angeles Times  latimes     Los Angeles, CA
# 2 759251   CNN                CNN
# 3 807095   The New York Times nytimes     New York City
# 4 1367531  Fox News           FoxNews     U.S.A.
#   description
# 1 News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors.
# 2 Its our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app <f0><U+009F><U+0093><U+00B2>https://t.co/Xgo5kjIt8c
# 3 Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/UVJRxNXe00 to share news tips.
# 4 Americas Strongest Primetime Lineup Anywhere! Follow America's #1 cable news network, delivering you breaking news, insightful analysis, and must-see videos.
#   url                    protected followers_count friends_count listed_count
# ...

# %%
str(data.frame(usrs))
# Out:
# 'data.frame':	4 obs. of  20 variables:
#  $ user_id               : chr  "16664681" "759251" "807095" "1367531"
#  $ name                  : chr  "Los Angeles Times" "CNN" "The New York Times" "Fox News"
#  $ screen_name           : chr  "latimes" "CNN" "nytimes" "FoxNews"
#  $ location              : chr  "Los Angeles, CA" "" "New York City" "U.S.A."
#  $ description           : chr  "News from Los Angeles and the world. Staffed by http://t.co/zb8HyvYyAJ editors." "Its our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNN"| __truncated__ "Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visi"| __truncated__ "Americas Strongest Primetime Lineup Anywhere! Follow America's #1 cable news network, delivering you breaking "| __truncated__
#  $ url                   : chr  "http://t.co/JvbZRDfNzf" "http://t.co/IaghNW8Xm2" "http://t.co/ahvuWqicF9" "http://t.co/ZYG58XZtAC"
# ...

# %%
tweets_data(usrs)
# Out:
#   status_id          created_at          user_id  screen_name
# 1 959910643137736706 2018-02-03 22:05:06 16664681 latimes
# 2 959916961789603845 2018-02-03 22:30:12 759251   CNN
# 3 959918183602884610 2018-02-03 22:35:04 807095   nytimes
# 4 959919195269091328 2018-02-03 22:39:05 1367531  FoxNews
#   text
# 1 Africans targeted, suspect arrested in string of shootings in Italian city where teen was slain https://t.co/cmrDR588oJ
# 2 France jails Islamic scholar on rape charge, judicial source says https://t.co/nqI0fWVgsq https://t.co/zqpgoIo3Z9
# 3 So much for all those songs and books and movies about the irresistible charms of the boy, or girl, next door https://t.co/HVfaQ8OFcR
# 4 Former @FBI Asst. Director Bill Gavin: "There's only a handful of people whose [badges are] now tarnished, and they https://t.co/c7YiTVZkv7
#   source       reply_to_status_id reply_to_user_id reply_to_screen_name
# 1 Hootsuite    NA                 NA               NA
# ...
